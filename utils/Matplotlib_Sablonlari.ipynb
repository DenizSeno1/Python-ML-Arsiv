# %% [markdown]
# # 📊 MATPLOTLIB GÖRSELLEŞTİRME ŞABLONLARI
#
# > **🎯 AMAÇ:** ML modelleri için hazır grafik şablonları koleksiyonu.
# > **📋 KULLANIM:** İhtiyacınız olan grafiğin kodunu kopyalayıp projenize yapıştırın.
#
# ### 📑 İÇERİK
# 1. **Gerçek vs Tahmin** (Scatter Plot)
# 2. **Regresyon Çizgisi** (Tek Değişken)
# 3. **Hata Analizi** (Residuals)
# 4. **Özellik Önemi** (Feature Importance)
# 5. **Model Karşılaştırma** (Bar Chart)
# 6. **Confusion Matrix** (Sınıflandırma)
# 7. **Learning Curve** (Eğitim Eğrisi)

# %% [markdown]
# ### 1️⃣ SCATTER PLOT: GERÇEK vs TAHMİN
# *Regresyon modellerinde tahminlerin başarımını görselleştirmek için.*

# %%
import matplotlib.pyplot as plt

def plot_actual_vs_predicted(y_test, y_pred, title="Gerçek vs Tahmin"):
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.6, color='blue', edgecolors='navy', s=50)
    
    min_val = min(min(y_test), min(y_pred))
    max_val = max(max(y_test), max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Mükemmel Tahmin')
    
    plt.xlabel('Gerçek Değerler')
    plt.ylabel('Tahmin Edilen Değerler')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ### 2️⃣ REGRESYON ÇİZGİSİ
# *Basit veya Polinom Regresyon için modelin (çizginin) veriye uyumu.*

# %%
def plot_regression_line(X, y, model, title="Regresyon"):
    plt.figure(figsize=(10, 6))
    
    # Veriyi düzleştir ve sırala
    X_flat = X.ravel() if hasattr(X, 'ravel') else np.array(X).ravel()
    y_flat = y.ravel() if hasattr(y, 'ravel') else np.array(y).ravel()
    sort_idx = X_flat.argsort()
    
    plt.scatter(X_flat[sort_idx], y_flat[sort_idx], color='red', alpha=0.6, label='Gerçek Veri')
    
    # Tahmin çizgisi
    X_line = np.linspace(X_flat.min(), X_flat.max(), 100).reshape(-1, 1)
    y_line = model.predict(X_line)
    plt.plot(X_line, y_line, color='blue', linewidth=2, label='Model Tahmini')
    
    plt.title(title, fontsize=14, fontweight='bold')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ### 3️⃣ RESIDUAL PLOT (HATA ANALİZİ)
# *Hataların rastgele dağılıp dağılmadığını (homoscedasticity) kontrol etmek için.*

# %%
def plot_residuals(y_test, y_pred, title="Residual Plot"):
    residuals = y_test - y_pred
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Scatter
    axes[0].scatter(y_pred, residuals, alpha=0.6, color='purple')
    axes[0].axhline(y=0, color='red', linestyle='--')
    axes[0].set_title('Hata Dağılımı')
    axes[0].grid(True, alpha=0.3)
    
    # Histogram
    axes[1].hist(residuals, bins=30, color='teal', edgecolor='black', alpha=0.7)
    axes[1].axvline(x=0, color='red', linestyle='--')
    axes[1].set_title('Hata Histogramı')
    axes[1].grid(True, alpha=0.3)
    
    plt.suptitle(title, fontsize=16, fontweight='bold')
    plt.show()

# %% [markdown]
# ### 4️⃣ FEATURE IMPORTANCE (ÖZELLİK ÖNEMİ)
# *Random Forest, Decision Tree gibi ağaç bazlı modellerde hangi özelliğin önemli olduğunu görmek için.*

# %%
def plot_feature_importance(model, feature_names=None, top_n=10, title="Özellik Önemi"):
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1][:top_n]
    
    if feature_names is None:
        feature_names = [f"Özellik {i}" for i in range(len(importances))]
    
    plt.figure(figsize=(10, 6))
    plt.barh(range(len(indices)), importances[indices], color='steelblue', edgecolor='navy')
    plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
    plt.gca().invert_yaxis()
    plt.title(title, fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3, axis='x')
    plt.show()

# %% [markdown]
# ### 5️⃣ CONFUSION MATRIX
# *Sınıflandırma modellerinin performansını detaylı görmek için.*

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, labels=None, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap='Blues')
    plt.colorbar()
    
    if labels is None:
        labels = [f"Sınıf {i}" for i in range(len(cm))]
    
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black",
                    fontweight='bold')
    
    plt.xlabel('Tahmin Edilen')
    plt.ylabel('Gerçek')
    plt.title(title, fontweight='bold')
    plt.show()
