# %% [markdown]
# # 🟥 CONFUSION MATRIX (KARMAŞIKLIK MATRİSİ)
# > **🎯 AMAÇ:** Modelin hangi sınıfları karıştırdığını görsel analiz
# > **📥 GİRDİ:** y_test, y_pred
# > **📤 ÇIKTI:** Ham + normalize CM, TP/TN/FP/FN analizi
# ### 🔧 YORUM
# ```
#            Tahmin
#            Neg  Pos
# Gerçek Neg [TN | FP]
#        Pos [FN | TP]
# ```
# - **FP (Tip I):** Yanlış alarm  |  **FN (Tip II):** Kaçırılan pozitif

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
print('=' * 50 + '\n🟥 CONFUSION MATRIX BAŞLATILIYOR\n' + '=' * 50)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train.values.ravel())
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm_norm = confusion_matrix(y_test, y_pred, normalize='true')
print(f'\n📊 Confusion Matrix:\n{cm}')
if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
    print(f'\n🔢 TN={tn} | FP={fp} (Tip I) | FN={fn} (Tip II) | TP={tp}')
    print(f'   Precision: {tp/(tp+fp):.4f} | Recall: {tp/(tp+fn):.4f} | Specificity: {tn/(tn+fp):.4f}')

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', linewidths=0.5,
            annot_kws={'size': 14, 'weight': 'bold'}, ax=axes[0])
axes[0].set_title('Confusion Matrix (Ham)', fontweight='bold')
axes[0].set_xlabel('Tahmin'); axes[0].set_ylabel('Gerçek')
sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='YlOrRd',
            linewidths=0.5, vmin=0, vmax=1, ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalize)', fontweight='bold')
axes[1].set_xlabel('Tahmin'); axes[1].set_ylabel('Gerçek')
plt.tight_layout(); plt.show()
print('\n✅ İşlem Tamamlandı.')
