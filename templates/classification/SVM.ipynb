# %% [markdown]
# # 📊 SUPPORT VECTOR MACHINE (SVM)
#
# > **🎯 AMAÇ:** Verileri en iyi ayıran çizgiyi/düzlemi bulmak
# > **📥 GİRDİ:** X_train, y_train (Bellekten - Ölçeklenmiş)
# > **📤 ÇIKTI:** Confusion Matrix, Doğruluk Oranı
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Veri setinde kenar (margin) netse
# - Yüksek boyutlu uzaylarda etkilidir
#
# ### 🔧 PARAMETRELER
# - `kernel='rbf'` (Varsayılan, Doğrusal olmayan)
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score

print("=" * 40)
print("SUPPORT VECTOR MACHINE (SVM) BAŞLATILIYOR")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
# kernel='rbf' -> Radyal Tabanlı Fonksiyon (Genel amaçlı)
# kernel='linear' -> Doğrusal ayrılabilir veriler için
svc_model = SVC(kernel='rbf', random_state=0)
svc_model.fit(X_train, y_train.values.ravel())
print("✅ Model Eğitildi (Kernel: RBF).")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = svc_model.predict(X_test)
print("✅ Tahminler Yapıldı.")

# 3. DEĞERLENDİRME
# ---------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("\nKarmaşıklık Matrisi (Confusion Matrix):")
print(cm)
print(f"\n🎯 DOĞRULUK ORANI (ACCURACY): %{acc*100:.2f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={'size': 14})
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değerler')
plt.title(f'SVM Classifier (Başarı: %{acc*100:.1f})')
plt.show()

print("\n✅ İşlem Tamamlandı.")
