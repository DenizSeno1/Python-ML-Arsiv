# %% [markdown]
# # 📊 GAUSSIAN NAIVE BAYES
#
# > **🎯 AMAÇ:** Olasılık temelli hızlı sınıflandırma yapmak
# > **📥 GİRDİ:** X_train, y_train (Bellekten - Ölçeklenmiş)
# > **📤 ÇIKTI:** Confusion Matrix, Doğruluk Oranı
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Veri seti çok büyükse (Hızlıdır)
# - Özellikler birbirinden bağımsızsa
#
# ### 🔧 ÇEŞİTLERİ
# - **Bernoulli:** 0/1 (İkili) veriler için
# - **Gaussian:** Sürekli (Ondalıklı) veriler için
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score

print("=" * 40)
print("GAUSSIAN NAIVE BAYES BAŞLATILIYOR")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
# GaussianNB: Özelliklerin normal dağıldığını varsayar
gnb = GaussianNB()
gnb.fit(X_train, y_train.values.ravel())
print("✅ Model Eğitildi.")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = gnb.predict(X_test)
print("✅ Tahminler Yapıldı.")

# 3. DEĞERLENDİRME
# ---------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("\nKarmaşıklık Matrisi (Confusion Matrix):")
print(cm)
print(f"\n🎯 DOĞRULUK ORANI (ACCURACY): %{acc*100:.2f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={'size': 14})
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değerler')
plt.title(f'Gaussian Naive Bayes (Başarı: %{acc*100:.1f})')
plt.show()

print("\n✅ İşlem Tamamlandı.")
