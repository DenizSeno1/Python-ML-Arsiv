# %% [markdown]
# # 📊 K-NEAREST NEIGHBORS (K-EN YAKIN KOMŞU)
#
# > **🎯 AMAÇ:** Benzer özelliklere sahip verileri gruplamak
# > **📥 GİRDİ:** X_train, y_train (Bellekten - Ölçeklenmiş)
# > **📤 ÇIKTI:** Confusion Matrix, Doğruluk Oranı
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Veri setinde belirgin kümeler varsa
# - Basit ve anlaşılır bir model isteniyorsa
#
# ### 🔧 PARAMETRELER
# - `n_neighbors=5` (Komşu Sayısı)
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

print("=" * 40)
print("K-NEAREST NEIGHBORS (KNN) BAŞLATILIYOR")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
# n_neighbors: Bakılacak komşu sayısı (Genelde 5 seçilir)
# metric='minkowski', p=2 -> Öklid mesafesi (Standart)
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
knn.fit(X_train, y_train.values.ravel())
print("✅ Model Eğitildi (K=5).")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = knn.predict(X_test)
print("✅ Tahminler Yapıldı.")

# 3. DEĞERLENDİRME
# ---------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("\nKarmaşıklık Matrisi (Confusion Matrix):")
print(cm)
print(f"\n🎯 DOĞRULUK ORANI (ACCURACY): %{acc*100:.2f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={'size': 14})
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değerler')
plt.title(f'K-Nearest Neighbors (K=5, Başarı: %{acc*100:.1f})')
plt.show()

print("\n✅ İşlem Tamamlandı.")
