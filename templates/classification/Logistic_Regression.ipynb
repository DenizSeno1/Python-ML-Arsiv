# %% [markdown]
# # 📊 LOJİSTİK REGRESYON
#
# > **🎯 AMAÇ:** İki veya daha fazla sınıfı ayırt etmek (0/1)
# > **📥 GİRDİ:** X_train, y_train (Bellekten - Ölçeklenmiş)
# > **📤 ÇIKTI:** Confusion Matrix, Doğruluk Oranı, Grafik
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Hedef değişken kategorikse (Evet/Hayır, Spam/Değil)
# - Sonuç bir ihtimal ise (%80 Evet gibi)
#
# ### 🔧 SONRASI
# - KNN veya SVM ile karşılaştırılabilir
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

print("=" * 40)
print("LOJİSTİK REGRESYON BAŞLATILIYOR")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
# X_train ve y_train bellekte hazır olmalı
log_reg = LogisticRegression(random_state=0)
log_reg.fit(X_train, y_train.values.ravel())
print("✅ Model Eğitildi.")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = log_reg.predict(X_test)
print("✅ Tahminler Yapıldı.")

# 3. DEĞERLENDİRME
# ---------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("\nKarmaşıklık Matrisi (Confusion Matrix):")
print(cm)
print(f"\n🎯 DOĞRULUK ORANI (ACCURACY): %{acc*100:.2f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={'size': 14})
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değerler')
plt.title(f'Logistic Regression (Başarı: %{acc*100:.1f})')
plt.show()

print("\n✅ İşlem Tamamlandı.")
