# %% [markdown]
# # 🌲 RANDOM FOREST CLASSIFIER (RASTGELE ORMAN)
#
# > **🎯 AMAÇ:** Birden çok karar ağacı ile daha güçlü tahmin
# > **📥 GİRDİ:** X_train, y_train (Bellekten - Ölçeklenmiş)
# > **📤 ÇIKTI:** Confusion Matrix, Doğruluk Oranı
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - En yüksek doğruluk istendiğinde (Genelde en iyisidir)
# - Overfitting (aşırı öğrenme) riskini azaltmak için
#
# ### 🔧 PARAMETRELER
# - `n_estimators=10` (Ağaç Sayısı)
# - `criterion='entropy'` (Bilgi Kazancı)
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

print("=" * 40)
print("🌲 RANDOM FOREST CLASSIFIER BAŞLATILIYOR")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
rf_model = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
rf_model.fit(X_train, y_train.values.ravel())
print("✅ Model Eğitildi.")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = rf_model.predict(X_test)
print("✅ Tahminler Yapıldı.")

# 3. DEĞERLENDİRME
# ---------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("\nKarmaşıklık Matrisi (Confusion Matrix):")
print(cm)
print(f"\n🎯 DOĞRULUK ORANI (ACCURACY): %{acc*100:.2f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={'size': 14})
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değerler')
plt.title(f'Random Forest (Başarı: %{acc*100:.1f})')
plt.show()

print("\n✅ İşlem Tamamlandı.")
