# %% [markdown]
# # 📊 ÇOKLU DOĞRUSAL REGRESYON
#
# > **🎯 AMAÇ:** Çok sebep → Tek sonuç (Çok boyutlu düzlem)
# > **📥 GİRDİ:** X_train, y_train (Bellekten)
# > **📤 ÇIKTI:** y_pred, R² skoru, İstatistik raporu
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Birden fazla bağımsız değişken varsa
# - Örn: Yaş + Boy + Kilo → Sağlık Skoru
#
# ### 🔧 SONRASI
# - Backward Elimination ile iyileştirilebilir
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

print("=" * 40)
print("📊 ÇOKLU DOĞRUSAL REGRESYON")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print("✅ Model eğitildi")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = regressor.predict(X_test)
print("✅ Tahminler yapıldı")

# 3. SONUÇLAR
# ---------------------------------------------------
r2 = r2_score(y_test, y_pred)
print(f"\n🎯 R² Başarı Skoru: {r2:.4f}")

# 4. GÖRSELLEŞTİRME (Gerçek vs Tahmin)
# ---------------------------------------------------
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='red', alpha=0.6, label='Tahminler')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'b--', label='Mükemmel Tahmin')
plt.xlabel('Gerçek Değerler')
plt.ylabel('Tahmin Edilen')
plt.title(f'Çoklu Doğrusal Regresyon (R² = {r2:.3f})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 5. İSTATİSTİK RAPORU (OLS)
# ---------------------------------------------------
X_train_ols = np.append(arr=np.ones((len(X_train), 1)).astype(int), values=X_train, axis=1)
model_ols = sm.OLS(y_train, X_train_ols).fit()
print(model_ols.summary())
