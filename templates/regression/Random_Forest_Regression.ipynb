# %% [markdown]
# # 🌲 RANDOM FOREST REGRESYONU
#
# > **🎯 AMAÇ:** Çok ağacın kolektif zekası (En güçlü model!)
# > **📥 GİRDİ:** X_train, y_train (Bellekten)
# > **📤 ÇIKTI:** y_pred, R² skoru, Grafik
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - En hassas sonuç istiyorsan
# - Genelde en iyi performansı verir
#
# ### 🔧 PARAMETRELER
# - `n_estimators=10` (Ağaç Sayısı)
# - Fazla ağaç → Yavaş ama hassas
# - Az ağaç → Hızlı ama az hassas
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

print("=" * 40)
print("🌲 RANDOM FOREST REGRESYONU")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
N_TREES = 10 
rf_model = RandomForestRegressor(n_estimators=N_TREES, random_state=0)
rf_model.fit(X_train, y_train.values.ravel())
print(f"✅ Random Forest modeli eğitildi ({N_TREES} ağaç)")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = rf_model.predict(X_test)
print("✅ Tahminler yapıldı")

# 3. SONUÇLAR
# ---------------------------------------------------
r2 = r2_score(y_test, y_pred)
print(f"\n🎯 R² Başarı Skoru: {r2:.4f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(10, 6))

# Veriyi sırala
sort_indices = X_train.ravel().argsort()
X_train_sorted = X_train[sort_indices]
y_train_sorted = y_train.iloc[sort_indices]

# Gerçek veri
plt.scatter(X_train_sorted, y_train_sorted, color='red', alpha=0.6, label='Gerçek Veri')

# Tahmin eğrisi (Yüksek çözünürlük)
X_grid = np.arange(min(X_train), max(X_train), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))

# Random Forest tahmini
plt.plot(X_grid, rf_model.predict(X_grid), color='blue', linewidth=2, label=f'Random Forest ({N_TREES} Ağaç)')

plt.title(f'Random Forest Regresyonu (R² = {r2:.3f})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 5. ÖZELLİK ÖNEMİ
# ---------------------------------------------------
print("\n🔍 ÖZELLİK ÖNEMİ")
feature_importances = rf_model.feature_importances_
for i, importance in enumerate(feature_importances):
    print(f"   Özellik {i}: {importance:.4f} ({importance*100:.1f}%)")
