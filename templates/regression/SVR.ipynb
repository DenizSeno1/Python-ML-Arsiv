# %% [markdown]
# # 🔮 SUPPORT VECTOR REGRESSION (SVR)
#
# > **🎯 AMAÇ:** Karmaşık, kıvrımlı ilişkileri modellemek
# > **📥 GİRDİ:** X_train, y_train (Bellekten)
# > **📤 ÇIKTI:** y_pred, R² skoru, Eğri grafik
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Polinom yeterli gelmiyorsa
# - Veri çok karmaşık ve kıvrımlıysa
# - Örn: Borsa tahmini, fiziksel formüller
#
# ### ⚠️ DİKKAT
# Hem X hem y ölçeklendirilmeli! (StandardScaler)
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

print("=" * 40)
print("🔮 SUPPORT VECTOR REGRESSION (SVR)")
print("=" * 40)

# 1. Y ÖLÇEKLEME
# ---------------------------------------------------
# SVR için y de ölçeklenmeli
sc_y = StandardScaler()
y_train_scaled = sc_y.fit_transform(y_train.values.reshape(-1, 1))
print("✅ y_train ölçeklendirildi")

# 2. MODEL VE EĞİTİM
# ---------------------------------------------------
# kernel='rbf': Radial Basis Function (Kıvrımlı)
svr_model = SVR(kernel='rbf')
svr_model.fit(X_train, y_train_scaled.ravel())
print("✅ SVR modeli eğitildi")

# 3. TAHMİN
# ---------------------------------------------------
y_pred_scaled = svr_model.predict(X_test)
y_pred = sc_y.inverse_transform(y_pred_scaled.reshape(-1, 1))
print("✅ Tahminler yapıldı")

# 4. SONUÇLAR
# ---------------------------------------------------
r2 = r2_score(y_test, y_pred)
print(f"\n🎯 R² Başarı Skoru: {r2:.4f}")

# 5. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(10, 6))

# Veriyi sırala
sort_indices = X_train.ravel().argsort()
X_train_sorted = X_train[sort_indices]
y_train_sorted = y_train.iloc[sort_indices]

# Gerçek veri
plt.scatter(X_train_sorted, y_train_sorted, color='red', alpha=0.6, label='Gerçek Veri')

# SVR Tahmini
y_svr_scaled = svr_model.predict(X_train_sorted)
y_svr_pred = sc_y.inverse_transform(y_svr_scaled.reshape(-1, 1))

plt.plot(X_train_sorted, y_svr_pred, color='blue', linewidth=2, label='SVR Tahmini')

plt.title(f'SVR Regresyon (R² = {r2:.3f})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
