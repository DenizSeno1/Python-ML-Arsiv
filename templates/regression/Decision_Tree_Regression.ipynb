# %% [markdown]
# # 🌳 KARAR AĞACI REGRESYONU
#
# > **🎯 AMAÇ:** Basamaklı/Aralıklı tahminler
# > **📥 GİRDİ:** X_train, y_train (Bellekten)
# > **📤 ÇIKTI:** y_pred, R² skoru, Basamaklı grafik
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Veri kategorik aralıklara bölünebiliyorsa
# - Örn: Maaş aralıkları, yaş grupları
# - Scaling gerektirmez (ama zaten yaptık)
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

print("=" * 40)
print("🌳 KARAR AĞACI REGRESYONU")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
# random_state=0: Her çalıştırmada aynı sonuç
dt_model = DecisionTreeRegressor(random_state=0)
dt_model.fit(X_train, y_train)
print("✅ Karar Ağacı modeli eğitildi")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = dt_model.predict(X_test)
print("✅ Tahminler yapıldı")

# 3. SONUÇLAR
# ---------------------------------------------------
r2 = r2_score(y_test, y_pred)
print(f"\n🎯 R² Başarı Skoru: {r2:.4f}")

# 4. GÖRSELLEŞTİRME (Basamaklı Yapı)
# ---------------------------------------------------
plt.figure(figsize=(10, 6))

# Veriyi sırala
sort_indices = X_train.ravel().argsort()
X_train_sorted = X_train[sort_indices]
y_train_sorted = y_train.iloc[sort_indices]

# Gerçek veri
plt.scatter(X_train_sorted, y_train_sorted, color='red', alpha=0.6, label='Gerçek Veri')

# Yüksek çözünürlüklü grid (Basamakları görmek için)
X_grid = np.arange(min(X_train), max(X_train), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))

# Tahmin
plt.plot(X_grid, dt_model.predict(X_grid), color='blue', linewidth=2, label='Karar Ağacı Tahmini')

plt.title(f'Karar Ağacı Regresyonu (R² = {r2:.3f})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
