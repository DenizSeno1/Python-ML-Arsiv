# %% [markdown]
# # 📈 BASİT DOĞRUSAL REGRESYON
#
# > **🎯 AMAÇ:** Tek sebep → Tek sonuç (Düz çizgi ilişkisi)
# > **📥 GİRDİ:** X_train, y_train (Bellekten)
# > **📤 ÇIKTI:** y_pred (Tahminler), R² skoru, Grafik
#
# ### ⏱️ NE ZAMAN KULLANILIR?
# - Tek bir bağımsız değişken varsa
# - İlişki düz çizgi gibi görünüyorsa
#
# ### 📊 ÖRNEK
# - Reklam Harcaması → Satış Miktarı
#
# ---
#
# ### ⚠️ UYARI
# Bu dosyayı çalıştırmadan **ÖNCE** mutlaka şu komutu çalıştırın:
# ```python
# %run Veri_On_Isleme.py
# ```
# (X_train, y_train bellekte olmalı)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

print("=" * 40)
print("📈 BASİT DOĞRUSAL REGRESYON")
print("=" * 40)

# 1. MODEL VE EĞİTİM
# ---------------------------------------------------
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print("✅ Model eğitildi")

# 2. TAHMİN
# ---------------------------------------------------
y_pred = regressor.predict(X_test)
print("✅ Tahminler yapıldı")

# 3. SONUÇLAR
# ---------------------------------------------------
r2 = r2_score(y_test, y_pred)
print(f"\n🎯 R² Başarı Skoru: {r2:.4f}")

# 4. GÖRSELLEŞTİRME
# ---------------------------------------------------
plt.figure(figsize=(10, 6))

# Tek sütun kontrolü
if hasattr(X_train, 'shape') and len(X_train.shape) > 1 and X_train.shape[1] > 1:
    plt.scatter(y_test, y_pred, color='red', alpha=0.6, label='Tahminler')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'b--', label='Mükemmel Tahmin')
    plt.xlabel('Gerçek Değerler')
    plt.ylabel('Tahmin Edilen')
else:
    # Tek sütunsa çizgi grafiği
    X_flat = np.array(X_train).ravel()
    sorted_idx = X_flat.argsort()
    X_sorted = X_flat[sorted_idx].reshape(-1, 1)
    
    plt.scatter(X_train, y_train, color='red', label='Gerçek Veri', alpha=0.6)
    plt.plot(X_sorted, regressor.predict(X_sorted), color='blue', linewidth=2, label='Tahmin Çizgisi')
    plt.xlabel('Bağımsız Değişken (X)')
    plt.ylabel('Hedef Değişken (y)')

plt.title(f'Basit Doğrusal Regresyon (R² = {r2:.3f})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
