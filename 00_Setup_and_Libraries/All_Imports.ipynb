# %% [markdown]
# # 📦 Tüm Kütüphaneler (All Imports)
#
# Bu dosya, makine öğrenmesi projelerinde ihtiyaç duyabileceğin tüm temel ve ileri seviye kütüphaneleri barındırır. Yeni bir projeye başlarken buradaki hücreleri kopyalayıp, projenin başına yapıştırabilirsin.

# %%
# ---------------------------------------------------------
# 1. TEMEL VERİ İŞLEME VE MATEMATİK
# ---------------------------------------------------------
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm, skew

# %%
# ---------------------------------------------------------
# 2. GÖRSELLEŞTİRME (EDA)
# ---------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Görselleştirme Ayarları
# %matplotlib inline
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %%
# ---------------------------------------------------------
# 3. VERİ ÖN İŞLEME VE ÖZELLİK MÜHENDİSLİĞİ (PREPROCESSING)
# ---------------------------------------------------------
# Eksik Veri Doldurma
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.experimental import enable_iterative_imputer # IterativeImputer için gerekli
from sklearn.impute import IterativeImputer

# Encoding (Kategorik değişkenleri sayısallaştırma)
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
import category_encoders as ce  # Target Encoding, Frequency Encoding vb. için

# Scaling (Ölçeklendirme)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# Özellik Üretimi (Feature Creation)
from sklearn.preprocessing import PolynomialFeatures

# %%
# ---------------------------------------------------------
# 4. MODELLEME VE DEĞERLENDİRME ARAÇLARI
# ---------------------------------------------------------
# Veri Bölme ve Çapraz Doğrulama
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score, GridSearchCV

# Hata Metrikleri (Regression)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Hata Metrikleri (Classification)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %%
# ---------------------------------------------------------
# 5. MAKİNE ÖĞRENMESİ MODELLERİ
# ---------------------------------------------------------
# Lineer Modeller
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, LogisticRegression

# Ağaç Tabanlı Modeller (Klasik)
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import ExtraTreesRegressor, ExtraTreesClassifier

# Gelişmiş Ağaç Tabanlı Modeller (GBM)
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor, CatBoostClassifier

# Ensemble Meta-Modelleri (Stacking / Voting)
from sklearn.ensemble import StackingRegressor, StackingClassifier, VotingRegressor, VotingClassifier

# %%
# ---------------------------------------------------------
# 6. İLERİ SEVİYE ARAÇLAR (OPTUNA, SHAP & OUTLIER)
# ---------------------------------------------------------
# Hiperparametre Optimizasyonu
import optuna
from optuna.integration import LightGBMPruningCallback, XGBoostPruningCallback

# Explainable AI (Modeli Yorumlama)
import shap

# Isolation Forest (Aykırı Değer Tespiti için Makine Öğrenmesi)
from sklearn.ensemble import IsolationForest
